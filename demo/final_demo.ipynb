# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras.applications import ResNet50
import numpy as np
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
from google.colab import drive
drive.mount('/content/drive')
def get_resnet_data():
    data = np.load('/content/drive/My Drive/Colab Notebooks/demo/resnet50_embeddings_x_test.npz')
    x_test_embeddings = data['embeddings']
    y_test = data['labels']
    return x_test_embeddings, y_test

x_test_embeddings, y_test = get_resnet_data()
# Out:
# Mounted at /content/drive

# %%
model_path = "/content/drive/My Drive/Colab Notebooks/demo/resnet50_cd.h5"

# Load the model
model = tf.keras.models.load_model(model_path)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
pred= model.predict(x_test_embeddings)
np.argmax(pred, axis=1)

from sklearn.metrics import classification_report
print(classification_report(y_test, np.argmax(pred, axis=1)))
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
#               precision    recall  f1-score   support
#
#            0       0.93      0.86      0.89       187
#            1       0.91      0.95      0.93       189
#            2       0.86      0.86      0.86       201
#            3       0.78      0.79      0.79       198
#            4       0.75      0.84      0.79       181
#            5       0.78      0.88      0.83       191
#            6       0.96      0.86      0.91       213
#            7       0.95      0.89      0.92       226
#            8       0.91      0.94      0.92       203
#            9       0.95      0.88      0.91       211
#
#     accuracy                           0.88      2000
#    macro avg       0.88      0.88      0.88      2000
# weighted avg       0.88      0.88      0.88      2000
